# %%
from pytube import YouTube
from IPython.display import Image, display
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
from googlesearch import search

# %%
def keyword_search():
    driver = webdriver.Chrome(executable_path='chromedriver.exe')

    search_query = 'https://www.youtube.com/ AND ' + keyword
    search_query

    driver.get('https:www.google.com')
    sleep(2)

    search_query1 = driver.find_element_by_name('q')
    search_query1.send_keys(search_query)
    sleep(0.5)
    search_query1.send_keys(Keys.RETURN)
    sleep(3)

    links = []
    for j in search(search_query, tld="co.in", num=10, stop=10, pause=2): 
        links.append(j) 
    for j in range(10):
        url = links[j]
        my_video = YouTube(url)
        print("\nVideo Title",j+1," : ")
        print(my_video.title)
        print("Link ",j+1," : ")
        print(links[j])
        driver.get(links[j])
        print("\nThumbnail: ")
        print(my_video.thumbnail_url)
        video_thumbnail=my_video.thumbnail_url
        display(Image(video_thumbnail))
        sleep(3)
    driver.quit()
    video_select=int(input("\nEnter link number (1-10) to be downloaded : "))
    url_link = links[video_select-1]
    return url_link

# %%
print("\Do you want to download via URL or search for keywords?: ")
print("\n1. Download via URL: ")
print("\n2. Search for Keywords: ")
choice=int(input("\nEnter choice : "))
# Out:
# \Do you want to download via URL or search for keywords?:
#
# 1. Download via URL:
#
# 2. Search for Keywords:
#
# Enter choice : 2

# %%
if choice==1:
    url=input("\nEnter URL : ")
elif choice==2:   
    keyword=input("\nEnter keyword to be searched : ")
    url=keyword_search()
# Out:
# Enter keyword to be searched : Top monuments in the world
#
# Video Title 1  :
# Top 15 Most Beautiful Monuments And Landmarks Around The World - In 4K
# Link  1  :
# https://www.youtube.com/watch?v=UTGvUjhCcro
#
# Thumbnail:
# https://i.ytimg.com/vi/UTGvUjhCcro/sddefault.jpg
# Video Title 2  :
# LANDMARKS OF THE WORLD - 100 Famous Landmarks for Kids
# Link  2  :
# https://www.youtube.com/watch?v=kDCXqaYWn-U
#
# Thumbnail:
# https://i.ytimg.com/vi/kDCXqaYWn-U/sddefault.jpg
# Video Title 3  :
# 15 Famous Monuments Around The World - Fun Facts Video | Kids Education by Mocomi
# Link  3  :
# https://www.youtube.com/watch?v=b4qkrzr7xvs
#
# Thumbnail:
# https://i.ytimg.com/vi/b4qkrzr7xvs/sddefault.jpg
# Video Title 4  :
# World Landmarks
# Link  4  :
# https://www.youtube.com/watch?v=Ru51XZX3Koc
#
# Thumbnail:
# https://i.ytimg.com/vi/Ru51XZX3Koc/sddefault.jpg
# Video Title 5  :
# Top 10 Most Famous Landmarks
# Link  5  :
# https://www.youtube.com/watch?v=A-dgLmKkRFM
#
# Thumbnail:
# https://i.ytimg.com/vi/A-dgLmKkRFM/sddefault.jpg
# Video Title 6  :
# Top 10 most famous Landmarks in the World for Children | Educational video for Kids | Kids Explorer
# Link  6  :
# https://www.youtube.com/watch?v=WpmhkxlnySc
#
# Thumbnail:
# https://i.ytimg.com/vi/WpmhkxlnySc/sddefault.jpg
# Video Title 7  :
# landmarks of the world | Famous landmarks |famous landmarks in the world |Top 10 landmarks for kids
# Link  7  :
# https://www.youtube.com/watch?v=UkA_8wdtRD0
#
# Thumbnail:
# https://i.ytimg.com/vi/UkA_8wdtRD0/sddefault.jpg
# Video Title 8  :
# Top 15 Famous Monuments Around The World || Landmarks || Amazing Architecture
# Link  8  :
# https://www.youtube.com/watch?v=LijcpOR9Awk
#
# Thumbnail:
# https://i.ytimg.com/vi/LijcpOR9Awk/sddefault.jpg
# Video Title 9  :
# Top 5 famous Landmarks of the world for children. educational video for kids. Sightseeings
# Link  9  :
# https://www.youtube.com/watch?v=CJx-FNQ_8wE
#
# Thumbnail:
# https://i.ytimg.com/vi/CJx-FNQ_8wE/sddefault.jpg
# Video Title 10  :
# Top 10 most visited monuments in the world.
# Link  10  :
# https://www.youtube.com/watch?v=5iww6yaaIFU
#
# Thumbnail:
# https://i.ytimg.com/vi/5iww6yaaIFU/sddefault.jpg
# Enter link number (1-10) to be downloaded : 1

# %%
my_video = YouTube(url)

print("Video Title: ")
print(my_video.title)

print("\nThumbnail: ")
print(my_video.thumbnail_url)
video_thumbnail=my_video.thumbnail_url
display(Image(video_thumbnail))

my_video = my_video.streams.get_highest_resolution()

print("\nDownloading........ ")
my_video.download()
# Out:
# Video Title:
# Top 15 Most Beautiful Monuments And Landmarks Around The World - In 4K
#
# Thumbnail:
# https://i.ytimg.com/vi/UTGvUjhCcro/sddefault.jpg
# Downloading........
# 'C:\\Users\\mgman\\Top 15 Most Beautiful Monuments And Landmarks Around The World - In 4K.mp4'
